# %% [markdown]
# 首先需要安装Pillow和matplotlib：pip install Pillow
#
# # 图片的打开与显示

# %%
from PIL import Image
img = Image.open('C:/dog.jpg')
img.show()

# %% [markdown]
# 虽然使用的是Pillow，但它是由PIL fork而来的，因此还是要从PIL中进行import的。使用open()函数来打开图片，使用show()函数来显示图片。
#
# 这种显示图片的方式是调用操作系统自带的图片浏览器来打开图片，有些时候这种方式不太方便，因此我们也可以使用另外一种方式，让程序来绘制图片。

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
img = Image.open('C:/dog.jpg')
plt.figure("dog")
plt.imshow(img)
plt.show()

# %% [markdown]
# 这种方法虽然复杂一点，但推荐使用这种方法，它使用一个matplotlib的库来绘制图片进行显示。matplotlib是一个专业绘图的库，相当于MATLAB中的plot，可以设置多个figure，设置figure标题，甚至可以使用subplot在一个figure中显示多张图片。
#
# figure默认是带axis的，如果没有需要，我们可以关掉。

# %%
plt.axie('off')

# %% [markdown]
# 打开图片后，可以使用一些属性来查看图片信息，如：

# %%
print(img.size) # 图像尺寸
print(img.mode) # 图像模式
print(img.format) # 图像格式
# Out:
# (195, 220)
# RGB
# JPEG

# %% [markdown]
# # 图片的保存

# %%
img.save('C:/dog.png')

# %% [markdown]
# 就一行代码，非常简单。这行代码不仅能保存图片，还能转换格式。如本例中，就由原来的jpg图片保存为了png图片。
